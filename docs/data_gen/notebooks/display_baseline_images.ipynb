# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import utils
import matplotlib.pyplot as plt

# %%
images = np.load('../data/images.npy')

# %%
fig, axs = plt.subplots(1, images.shape[0], figsize=(5 * images.shape[0], 5))
for i in range(images.shape[0]):
    axs[i].imshow(utils.normalize(images[i]))

# %%
max_dist_baselines = utils.get_max_distance_image(images)
fig, axs = plt.subplots(1, max_dist_baselines.shape[0], figsize=(5 * max_dist_baselines.shape[0], 5))
for i in range(max_dist_baselines.shape[0]):
    axs[i].imshow(utils.normalize(max_dist_baselines[i]))

# %%
blurred_baselines = utils.get_blurred_image(images, sigma=0)
fig, axs = plt.subplots(1, blurred_baselines.shape[0], figsize=(5 * blurred_baselines.shape[0], 5))
for i in range(blurred_baselines.shape[0]):
    axs[i].imshow(utils.normalize(blurred_baselines[i]))

# %%
uniform_baselines = utils.get_uniform_image(images)
fig, axs = plt.subplots(1, uniform_baselines.shape[0], figsize=(5 * uniform_baselines.shape[0], 5))
for i in range(uniform_baselines.shape[0]):
    axs[i].imshow(utils.normalize(uniform_baselines[i]))

# %%
mean_baselines = utils.get_mean_image(images, sigma=0.25)
fig, axs = plt.subplots(1, mean_baselines.shape[0], figsize=(5 * mean_baselines.shape[0], 5))
for i in range(mean_baselines.shape[0]):
    axs[i].imshow(utils.normalize(mean_baselines[i]))
